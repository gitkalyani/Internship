# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
## Connect to the driver

driver = webdriver.Chrome(r'C:\Users\ASUS\Downloads\chromedriver_win32\Chromedriver.exe')

# %%
# Opening the desired page on automated chrome browser

driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
Rank = []        
try:
    rank = driver.find_elements(By.XPATH, '//td[@align="center"][1]')
    for i in rank[0:30]:
        ranks = i.text
        Rank.append(ranks)
except NoSuchElementException:
        Rank.append('-')

# %%
Name = []        
try:
    name = driver.find_elements(By.XPATH, '//*[@id="mw-content-text"]/div/table/tbody/tr/td[2]')
    for i in name[1:31]:
        names = i.text
        Name.append(names)
except NoSuchElementException:
        Name.append('-')

# %%
Uploader = []        
try:
    uploader = driver.find_elements(By.XPATH, '//*[@id="mw-content-text"]/div/table/tbody/tr/td[3]')
    for i in uploader[0:30]:
        uploaders = i.text
        Uploader.append(uploaders)
except NoSuchElementException:
        Uploader.append('-')

# %%
Up_Date = []        
try:
    date = driver.find_elements(By.XPATH, '//*[@id="mw-content-text"]/div/table/tbody/tr/td[5]')
    for i in date[0:30]:
        dates = i.text
        Up_Date.append(dates)
except NoSuchElementException:
        Up_Date.append('-')

# %%
View = []        
try:
    view = driver.find_elements(By.XPATH, '//*[@id="mw-content-text"]/div/table/tbody/tr/td[4]')
    for i in view[0:30]:
        views = i.text
        View.append(views)
except NoSuchElementException:
        View.append('-')

# %% [markdown]
# ### Making DataFrame

# %%
df = pd.DataFrame({'Rank':Rank, 'Name':Name, 'Uploader':Uploader, 'Upload_Date':Up_Date, 'View':View})
df
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                          "Wheels on the Bus"[24]
# 8    9.                                "Uptown Funk"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                     "Axel F"[34]
# 14  15.                                      "Sugar"[35]
# ...

# %% [markdown]
# 2. Scrape the details teamIndia’sinternationalfixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1stODI)
# B) Series
# C) Place
# D) Date
# E) Time

# %%
## Connect to the driver

driver = webdriver.Chrome(r'C:\Users\ASUS\Downloads\chromedriver_win32\Chromedriver.exe')

# %%
# Opening the desired page on automated chrome browser

driver.get(' https://www.bcci.tv')

# %%
## Code for search button

search = driver.find_element(By.XPATH,"/html/body/nav/div[1]/button")

search.click()

# %%
## Code for international button

search = driver.find_element(By.XPATH,"/html/body/nav/div[1]/div[2]/ul[1]/li[2]")

search.click()

# %%
## Code for result button

search = driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div/ul/li[2]")

search.click()

# %%
## Code for more results button

search = driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div/div[4]/div/button")
search.click()

# %%
## Code for more results button

search = driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div/div[4]/div/button")
search.click()

# %%
## Code for more results button

search = driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div/div[4]/div/button")
search.click()

# %%
## Code for more results button

search = driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div/div[4]/div/button")
search.click()

# %%
Title = []
Series = []
Place = []
Date = []
Time = []

# %%
# For Title
try:
    title = driver.find_elements(By.XPATH, '//span[@class="matchOrderText ng-binding ng-scope"]')
    for i in title[0:40]:
        titles = i.text
        Title.append(titles)
except NoSuchElementException:
        Title.append('-')
Title =[i.replace("-"," ") for i in Title]           
        
#For Series
try:
    series = driver.find_elements(By.XPATH, '//h5[@class="match-tournament-name ng-binding"]')
    for i in series[0:40]:
        seriess = i.text
        Series.append(seriess)
except NoSuchElementException:
        Series.append('-')       
        
        
        
        

#For Place       
try:
    place = driver.find_elements(By.XPATH, '//*[@id="match-card"]/div[3]//span[2]')
    for i in place[0:40]:
        places = i.text
        Place.append(places)
except NoSuchElementException:
        Place.append('-')  
        
        
        
        
#For Date       
try:
    date = driver.find_elements(By.XPATH, '//div[@class="match-dates ng-binding"]')
    for i in date[0:40]:
        dates = i.text
        Date.append(dates)
except NoSuchElementException:
        Date.append('-')    
        
        
        
        
#For Time        
try:
    time = driver.find_elements(By.XPATH, '//div[@class="match-time no-margin ng-binding"]')
    for i in time[0:40]:
        times = i.text
        Time.append(times)
except NoSuchElementException:
        Time.append('-')

# %% [markdown]
# ### Making DataFrame

# %%
df = pd.DataFrame({'Match_Title':Title, 'Series':Series, 'Place':Place, 'Date':Date, 'Time':Time})
df
# Out:
#      Match_Title                                          Series  \
# 0      3rd ODI                      AUSTRALIA TOUR OF INDIA 2023
# 1      2nd ODI                      AUSTRALIA TOUR OF INDIA 2023
# 2      1st ODI                      AUSTRALIA TOUR OF INDIA 2023
# 3     4th Test                      AUSTRALIA TOUR OF INDIA 2023
# 4     3rd Test                      AUSTRALIA TOUR OF INDIA 2023
# 5   Semi Final                     ICC WOMENS T20 WORLD CUP 2023
# 6     4th T20I                     ICC WOMENS T20 WORLD CUP 2023
# 7     3rd T20I                     ICC WOMENS T20 WORLD CUP 2023
# 8     2nd Test                      AUSTRALIA TOUR OF INDIA 2023
# 9     2nd T20I                     ICC WOMENS T20 WORLD CUP 2023
# 10    1st T20I                     ICC WOMENS T20 WORLD CUP 2023
# 11    1st Test                      AUSTRALIA TOUR OF INDIA 2023
# 12       Final       WOMENS T20I TRI-SERIES IN SOUTH AFRICA 2023
# ...

# %%
driver.close()

# %% [markdown]
# 3. Scrape the details of State-wise GDP ofIndia fromstatisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)- at current prices
# D) GSDP(19-20)- at current prices
# E) Share(18-19)
# F) GDP($ billion)

# %%
## Connect to the driver

driver = webdriver.Chrome(r'C:\Users\ASUS\Downloads\chromedriver_win32\Chromedriver.exe')

# %%
# Opening the desired page on automated chrome browser

driver.get(' http://statisticstimes.com')

# %%
## Code for economy button

search = driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/button")

search.click()

# %%
## Code for INDIA button

search = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')

search.click()

# %%
## Code for gdp of indian states button

search = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')

search.click()

# %%
Rank = []
State = []
GSDP_18_19 = []
GSDP_19_20 = []
Share_18_19 = []
GDP = []

# %%
# For Rank
try:
    rank = driver.find_elements(By.XPATH, '//*[@id="table_id"]/tbody/tr/td[1]')
    for i in rank[0:33]:
        ranks = i.text
        Rank.append(ranks)
except NoSuchElementException:
        Rank.append('-')
        
        
#For state
try:
    state = driver.find_elements(By.XPATH, '//*[@id="table_id"]/tbody/tr/td[2]')
    for i in state[0:33]:
        states = i.text
        State.append(states)
except NoSuchElementException:
        State.append('-')       
        
        
        
        

#For GSDP_18_19 = []        
try:
    gsdp1 = driver.find_elements(By.XPATH, '//*[@id="table_id"]/tbody/tr/td[4]')
    for i in gsdp1[0:33]:
        gsdp1s = i.text
        GSDP_18_19.append(gsdp1s)
except NoSuchElementException:
        GSDP_18_19.append('-')  
        
        
        
        
#For GSDP_19_20 = []        
try:
    gsdp2 = driver.find_elements(By.XPATH, '//*[@id="table_id"]/tbody/tr/td[3]')
    for i in gsdp2[0:33]:
        gsdp2s = i.text
        GSDP_19_20.append(gsdp2s)
except NoSuchElementException:
        GSDP_19_20.append('-')    
        
        
        
        
#For Share_18_19 = []        
try:
    share1 = driver.find_elements(By.XPATH, '//*[@id="table_id"]/tbody/tr/td[5]')
    for i in share1[0:33]:
        share1s = i.text
        Share_18_19.append(share1s)
except NoSuchElementException:
        Share_18_19.append('-')    
        
        
        
        
# For GDP = []        
try:
    gdp1 = driver.find_elements(By.XPATH, '//*[@id="table_id"]/tbody/tr/td[6]')
    for i in gdp1[0:33]:
        gdp1s = i.text
        GDP.append(gdp1s)
except NoSuchElementException:
        GDP.append('-')

# %% [markdown]
# ### Making DataFrame

# %%
df = pd.DataFrame({'Rank':Rank, 'State':State, 'GSDP_18_19':GSDP_18_19, 'GSDP_19_20':GSDP_19_20, 'Share_18_19':Share_18_19, 'GDP':GDP})
df
# Out:
#    Rank                      State GSDP_18_19 GSDP_19_20 Share_18_19      GDP
# 0     1                Maharashtra  2,632,792          -      13.94%  399.921
# 1     2                 Tamil Nadu  1,630,208  1,845,853       8.63%  247.629
# 2     3              Uttar Pradesh  1,584,764  1,687,818       8.39%  240.726
# 3     4                    Gujarat  1,502,899          -       7.96%  228.290
# 4     5                  Karnataka  1,493,127  1,631,977       7.91%  226.806
# 5     6                West Bengal  1,089,898  1,253,832       5.77%  165.556
# 6     7                  Rajasthan    942,586  1,020,989       4.99%  143.179
# 7     8             Andhra Pradesh    862,957    972,782       4.57%  131.083
# 8     9                  Telangana    861,031    969,604       4.56%  130.791
# 9    10             Madhya Pradesh    809,592    906,672       4.29%  122.977
# 10   11                     Kerala    781,653          -       4.14%  118.733
# ...

# %%
driver.close()

# %% [markdown]
# 4. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
## Connect to the driver

driver = webdriver.Chrome(r'C:\Users\ASUS\Downloads\chromedriver_win32\Chromedriver.exe')

# %%
# Opening the desired page on automated chrome browser

driver.get(' https://github.com')

# %%
## Code for option button

search = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[1]/div[2]/button/span")

search.click()

# %%
## Code for open source button

search = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button")

search.click()

# %%
## Code for trending button

search = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a")

search.click()

# %%
Title = []
Descr = []
Count = []
Language = []

# %%
# For Title
try:
    title = driver.find_elements(By.XPATH, '//span[@class="text-normal"]')
    for i in title[0:22]:
        titles = i.text
        Title.append(titles)
except NoSuchElementException:
        Title.append('-')
Title =[i.replace("/"," ") for i in Title]

        
#For Descr
try:
    descr = driver.find_elements(By.XPATH, '//p[@class="col-9 color-fg-muted my-1 pr-4"]')
    for i in descr[0:22]:
        descrs = i.text
        Descr.append(descrs)
except NoSuchElementException:
        Descr.append('-')       
        
        
        
        

#For Count = []        
try:
    count = driver.find_elements(By.XPATH, '/html/body/div/div[4]/main/div/div/div/article/div/a[2]')
    for i in count[0:22]:
        counts = i.text
        Count.append(counts)
except NoSuchElementException:
        Count.append('-')  
        
        
        
        
#For Language = []        
try:
    lang = driver.find_elements(By.XPATH, '//span[@class="d-inline-block ml-0 mr-3"]')
    for i in lang[0:22]:
        langs = i.text
        Language.append(langs)
except NoSuchElementException:
        Language.append('-')

# %% [markdown]
# ### Making DataFrame

# %%
df = pd.DataFrame({'Repository_Title':Title, 'Repository_Description':Descr, 'Contributers_Count':Count, 'Language_Used':Language})
df
# Out:
#      Repository_Title                             Repository_Description  \
# 0            xtekky    decentralising the Ai Industry, free gpt-4/3.5...
# 1         mitsuhiko    an experimental alternative to poetry/pip/pipe...
# 2      sindresorhus    😎 Awesome lists about all kinds of interesting...
# 3           Josh-XT    An Artificial Intelligence Automation Platform...
# 4       whoiskatrin          AI tool to build charts based on text input
# 5           Snaacky    Dark and Darker private server implementation ...
# 6           lvwzhen                                           ⚖️ AI 法律助手
# 7           GreyDGL             A GPT-empowered penetration testing tool
# 8   BigBrotherTrade                                                 交易模块
# 9           Dogtiti    🤖 Assemble, configure, and deploy autonomous A...
# 10      Developer-Y    List of Computer Science courses with video le...
# 11         roboflow    Examples and tutorials on using SOTA computer ...
# ...

# %% [markdown]
# 5. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board

# %%
## Connect to the driver

driver = webdriver.Chrome(r'C:\Users\ASUS\Downloads\chromedriver_win32\Chromedriver.exe')

# %%
# Opening the desired page on automated chrome browser

driver.get('https://www.billboard.com')

# %%
## Code for option button

search = driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[4]/div/div[1]/div[1]/button")

search.click()

# %%
## Code for charts button

search = driver.find_element(By.XPATH,"/html/body/div[3]/div[9]/div/div/div/ul/li[1]/h3/a")

search.click()

# %%
## Code for 100 songs button

search = driver.find_element(By.XPATH,"/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]")

search.click()

# %%
Song = []
Artist = []
LW_Rank = []
Peak = []
Weak = []

# %%
# For Song
try:
    song = driver.find_elements(By.XPATH, '//li[@class="lrv-u-width-100p"]//h3')
    for i in song[0:100]:
        songs = i.text
        Song.append(songs)
except NoSuchElementException:
        Song.append('-')


        
#For Artist
try:
    artist = driver.find_elements(By.XPATH, '//li[@class="lrv-u-width-100p"]/ul/li[1]/span')
    for i in artist[0:100]:
        artists = i.text
        Artist.append(artists)
except NoSuchElementException:
        Artist.append('-')       
        
        
        
        

#For LW_Rank        
try:
    lw = driver.find_elements(By.XPATH, '//*[@id="post-1479786"]/div[3]/div/div/div/div[2]/div/ul/li/ul/li[4]')
    for i in lw[0:100]:
        lws = i.text
        LW_Rank.append(lws)
except NoSuchElementException:
        LW_Rank.append('-')  
        
        
        
        
#For Peak        
try:
    peak = driver.find_elements(By.XPATH, '//*[@id="post-1479786"]/div[3]/div/div/div/div[2]/div/ul/li/ul/li[5]')
    for i in peak[0:100]:
        peaks = i.text
        Peak.append(peaks)
except NoSuchElementException:
        Peak.append('-')    
        
        
        
        

#For Weak       
try:
    weak = driver.find_elements(By.XPATH, '//*[@id="post-1479786"]/div[3]/div/div/div/div[2]/div/ul/li/ul/li[6]')
    for i in weak[0:100]:
        weaks = i.text
        Weak.append(weaks)
except NoSuchElementException:
        Weak.append('-')

# %% [markdown]
# ### Making DataFrame

# %%
df = pd.DataFrame({'Song_Name':Song, 'Artist_Name':Artist, 'Last_Week_Rank':LW_Rank, 'Peak_Rank':Peak,'Weaks_On_Board':Weak})
df
# Out:
#             Song_Name                              Artist_Name Last_Week_Rank  \
# 0           Kill Bill                                      SZA              4
# 1          Last Night                            Morgan Wallen              1
# 2             Flowers                              Miley Cyrus              3
# 3      Princess Diana                  Ice Spice & Nicki Minaj              -
# 4     Ella Baila Sola              Eslabon Armado X Peso Pluma             10
# ..                ...                                      ...            ...
# 95        Memory Lane                             Old Dominion             96
# 96         Love Again                            The Kid LAROI             88
# 97         '98 Braves                            Morgan Wallen            100
# 98          Di Que Si  Grupo Marca Registrada X Grupo Frontera              -
# 99  It Matters To Her                          Scotty McCreery              -
#
#    Peak_Rank Weaks_On_Board
# ...

# %%
driver.close()

# %% [markdown]
# 6. Scrape the details of Highest sellingnovels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
## Connect to the driver

driver = webdriver.Chrome(r'C:\Users\ASUS\Downloads\chromedriver_win32\Chromedriver.exe')

# %%
# Opening the desired page on automated chrome browser

driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
Name = []
Author = []
Volume = []
Publisher = []
Genre = []

# %%
# For Name
try:
    name = driver.find_elements(By.XPATH, '//*[@id="article-body-blocks"]/div/table/tbody/tr/td[2]')
    for i in name[0:100]:
        names = i.text
        Name.append(names)
except NoSuchElementException:
        Name.append('-')


        
#For Author
try:
    author = driver.find_elements(By.XPATH, '//*[@id="article-body-blocks"]/div/table/tbody/tr/td[3]')
    for i in author[0:100]:
        authors = i.text
        Author.append(authors)
except NoSuchElementException:
        Author.append('-')       
        
        
        
        

#For Volume        
try:
    volume = driver.find_elements(By.XPATH, '//*[@id="article-body-blocks"]/div/table/tbody/tr/td[4]')
    for i in volume[0:100]:
        volumes = i.text
        Volume.append(volumes)
except NoSuchElementException:
        Volume.append('-')  
        
        
        
        
#For Publisher        
try:
    publisher = driver.find_elements(By.XPATH, '//*[@id="article-body-blocks"]/div/table/tbody/tr/td[5] ')
    for i in publisher[0:100]:
        publishers = i.text
        Publisher.append(publishers)
except NoSuchElementException:
        Publisher.append('-')    
        
        
        
        

#For Genre       
try:
    genre = driver.find_elements(By.XPATH, '//*[@id="article-body-blocks"]/div/table/tbody/tr/td[6]')
    for i in genre[0:100]:
        genres = i.text
        Genre.append(genres)
except NoSuchElementException:
        Genre.append('-')

# %% [markdown]
# ### Making DataFrame

# %%
df = pd.DataFrame({'Book_Name':Name, ' Author_Name':Author, 'Volumes_Sold ':Volume, ' Publisher': Publisher, 'Genre':Genre})
df
# Out:
#                                             Book_Name       Author_Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_Sold         Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# 7. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
## Connect to the driver

driver = webdriver.Chrome(r'C:\Users\ASUS\Downloads\chromedriver_win32\Chromedriver.exe')

# %%
# Opening the desired page on automated chrome browser

driver.get(' https://www.imdb.com/list/ls095964455')

# %%
Name = []
Year = []
Genre = []
Time = []
Rating = []
Vote = []

# %%
# For Name
try:
    name = driver.find_elements(By.XPATH, '//*[@id="main"]/div/div[3]/div[3]/div/div/h3/a')
    for i in name[0:100]:
        names = i.text
        Name.append(names)
except NoSuchElementException:
        Name.append('-')


        
#For Year
try:
    year = driver.find_elements(By.XPATH, '//span[@class="lister-item-year text-muted unbold"]')
    for i in year[0:100]:
        years = i.text
        Year.append(years)
except NoSuchElementException:
        Year.append('-')       
        
        
        
        

#For Time        
try:
    time = driver.find_elements(By.XPATH, '//span[@class="runtime"]')
    for i in time[0:100]:
        times = i.text
        Time.append(times)
except NoSuchElementException:
        Time.append('-')  
        
        
        
        
#For Rating        
try:
    rating = driver.find_elements(By.XPATH, '//div[@class="ipl-rating-star small"]')
    for i in rating[0:100]:
        ratings = i.text
        Rating.append(ratings)
except NoSuchElementException:
        Rating.append('-')    
        
        
        
        

#For Genre       
try:
    genre = driver.find_elements(By.XPATH, '//span[@class="genre"]')
    for i in genre[0:100]:
        genres = i.text
        Genre.append(genres)
except NoSuchElementException:
        Genre.append('-')    
        
        
        
        
    
#For Vote       
try:
    vote = driver.find_elements(By.XPATH, '//span[@name="nv"]')
    for i in vote[0:100]:
        votes = i.text
        Vote.append(votes)
except NoSuchElementException:
        Vote.append('-')

# %% [markdown]
# ### Making DataFrame

# %%
df = pd.DataFrame({'Book_Name':Name, 'Year_Span':Year, ' Run_Time':Time, 'Ratings': Rating, 'Votes':Vote, 'Genre':Genre})
df
# Out:
#                          Book_Name    Year_Span  Run_Time Ratings      Votes  \
# 0                  Game of Thrones  (2011–2019)    57 min     9.2  2,153,568
# 1                  Stranger Things  (2016–2024)    51 min     8.7  1,235,598
# 2                 The Walking Dead  (2010–2022)    44 min     8.1  1,023,014
# 3                   13 Reasons Why  (2017–2020)    60 min     7.5    301,056
# 4                          The 100  (2014–2020)    43 min     7.6    259,994
# ..                             ...          ...       ...     ...        ...
# 95                           Reign  (2013–2017)    42 min     7.4     51,397
# 96  A Series of Unfortunate Events  (2017–2019)    50 min     7.8     63,437
# 97                  Criminal Minds     (2005– )    42 min     8.1    206,834
# 98           Scream: The TV Series  (2015–2019)    45 min       7     42,938
# 99      The Haunting of Hill House       (2018)   572 min     8.6    256,457
#
#                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# 8. Details of Datasetsfrom UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year

# %%
## Connect to the driver

driver = webdriver.Chrome(r'C:\Users\ASUS\Downloads\chromedriver_win32\Chromedriver.exe')

# %%
# Opening the desired page on automated chrome browser

driver.get(' https://archive.ics.uci.edu')

# %%
## Code for Show All Dataset button

search = driver.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/span[2]")

search.click()

# %%
DS_Name = []
D_Type = []
Task = []
Attri_Type = []
Instance = []
No_Of_Attri = []
Year = []

# %%
# For Dataset Name
try:
    name = driver.find_elements(By.XPATH, '*//body//table//tbody/tr/td/table/tbody/tr/td[1]/table/tbody/tr/td[2]/p')
    for i in name[0:622]:
        names = i.text
        DS_Name.append(names)
except NoSuchElementException:
        DS_Name.append('-')


        
#For Year
try:
    year = driver.find_elements(By.XPATH, '*//body/table/tbody/tr/td/table/tbody/tr/td[7]/p')
    for i in year[1:623]:
        years = i.text
        Year.append(years)
except NoSuchElementException:
        Year.append('-')       
        
        
        
        

#For D_Type        
try:
    dtype = driver.find_elements(By.XPATH, '*//body/table/tbody/tr/td/table/tbody/tr/td[2]/p')
    for i in dtype[2:624]:
        dtypes = i.text
        D_Type.append(dtypes)
except NoSuchElementException:
        D_Type.append('-')  
        
        
        
        
#For Task        
try:
    task = driver.find_elements(By.XPATH, '*//body/table/tbody/tr/td/table/tbody/tr/td[3]/p')
    for i in task[1:623]:
        tasks = i.text
        Task.append(tasks)
except NoSuchElementException:
        Task.append('-')    
        
        
        
        

#For Attri_Type       
try:
    attritype = driver.find_elements(By.XPATH, '*//body/table/tbody/tr/td/table/tbody/tr/td[4]/p')
    for i in attritype[1:623]:
        attritypes = i.text
        Attri_Type.append(attritypes)
except NoSuchElementException:
        Attri_Type.append('-')    
        
        
        
        
    
#For Instances       
try:
    instance = driver.find_elements(By.XPATH, '*//body/table/tbody/tr/td/table/tbody/tr/td[5]/p')
    for i in instance[1:624]:
        instances = i.text
        Instance.append(instances)
except NoSuchElementException:
        Instance.append('-')        
        
        
        
        
        
    
#For No_Of_Attri       
try:
    attrino = driver.find_elements(By.XPATH, '*//body/table/tbody/tr/td/table/tbody/tr/td[6]/p')
    for i in attrino[1:624]:
        attrinos = i.text
        No_Of_Attri.append(attrinos)
except NoSuchElementException:
        No_Of_Attri.append('-')

# %%
print(len(DS_Name),len(D_Type),len(Task),len(Attri_Type),len(Instance),len(No_Of_Attri),len(Year))
# Out:
# 622 622 622 622 622 622 622

# %% [markdown]
# ### Making DataFrame

# %%
df = pd.DataFrame({'DataSet_Name':DS_Name, 'Datatype':D_Type, 'Task':Task, 'Attribute_Type': Attri_Type, 'No_Of_Instances':Instance, 'No_Of_Attribute':No_Of_Attri, 'Year':Year})
df
# Out:
#                                           DataSet_Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                        Datatype                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...

# %%
driver.close()

# %% [markdown]
# 9. Scrape the details of Data science recruiters Url = https://www.naukri.com/hr-recruiters-consultants
# You have to find the following details:
# A) Name
# B) Designation
# C)Company
# D)Skills they hire for
# E) Location

# %%
## Connect to the driver

driver = webdriver.Chrome(r'C:\Users\ASUS\Downloads\chromedriver_win32\Chromedriver.exe')

# %%
# Opening the desired page on automated chrome browser

driver.get('https://www.naukri.com/hr-recruiters-consultants')

# %%
## Code for Recruiter button

search = driver.find_element(By.XPATH,"/html/body/div[1]/div/ul/li[2]/a/div")

search.click()

# %%
## Entering the job name

designation = driver.find_element(By.CLASS_NAME,"sugInp")

designation.send_keys('Data Science')

# %%
## Code for search button

search = driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button")

search.click()

# %%
Name = []
Designation = []
Company = []
Skill = []
Location = []

# %%
# For Name
try:
    name = driver.find_elements(By.XPATH, '//span[@class="fl ellipsis"]')
    for i in name[0:49]:
        names = i.text
        Name.append(names)
except NoSuchElementException:
        Name.append('-')


        
#For Designation
try:
    designation = driver.find_elements(By.XPATH, '//span[@class="ellipsis clr"]')
    for i in designation[0:49]:
        designations = i.text
        Designation.append(designations)
except NoSuchElementException:
        Designation.append('-')       
        
        
        
        

#For Company        
try:
    company = driver.find_elements(By.XPATH, '//*[@id="tabP-1"]/div/div/div/div/p/a[2]')
    for i in company[0:49]:
        companys = i.text
        Company.append(companys)
except NoSuchElementException:
        Company.append('-')  
        
        
        
        
#For Skill        
try:
    skill = driver.find_elements(By.XPATH, '//div[@class="hireSec highlightable"]')
    for i in skill[0:49]:
        skills = i.text
        Skill.append(skills)
except NoSuchElementException:
        Skill.append('-')    
        
        
        
        

#For Location       
try:
    location = driver.find_elements(By.XPATH, '//*[@id="tabP-1"]/div/div/div/div/p/span/small')
    for i in location[0:49]:
        locations = i.text
        Location.append(locations)
except NoSuchElementException:
        Location.append('-')

# %% [markdown]
# ### Making DataFrame

# %%
df = pd.DataFrame({'Name':Name, 'Designation':Designation, 'Company':Company, 'Skill_They_Hire':Skill, 'Location':Location})
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                                 Priyanka Akiri
# 14                                   Kapil Devang
# 15                             Mahesh Babu Channa
# 16                             Vaishnavi Kudalkar
# 17                                Sakshi Chhikara
# ...
